# %% [markdown]
# This notebook is collected from [Here](https://github.com/krishnaik06/Complete-Python-Bootcamp/tree/main).

# %% [markdown]
# #### Sets
# Sets are a built-in data type in Python used to store collections of unique items. They are unordered, meaning that the elements do not follow a specific order, and they do not allow duplicate elements. Sets are useful for membership tests, eliminating duplicate entries, and performing mathematical set operations like union, intersection, difference, and symmetric difference.

# %%
list1 = [1, 2, 3, 4, 5,2,4]
print(list1)
# Out:
# [1, 2, 3, 4, 5, 2, 4]

# %%
set1 = set(list1)
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
##create a set
my_set={1,2,3,4,5}
print(my_set)
print(type(my_set))

# %%
my_empty_set=set()
print(type(my_empty_set))

# %%
my_set=set([1,2,3,4,5,6])
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_empty_set=set([1,2,3,6,5,4,5,6])
print(my_empty_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
## Basics Sets Operation
## Adiing and Removing Elements
my_set.add(7)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.add(7)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
## Remove the elements from a set
my_set.remove(3)
print(my_set)
# Out:
# {1, 2, 4, 5, 6, 7}

# %%
my_set.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_set.remove(10)
#
# KeyError: 10

# %%
my_set.discard(11)
print(my_set)
# Out:
# {1, 2, 4, 5, 6, 7}

# %%
print(list(my_set).pop())
# Out:
# 7

# %%
my_set={1,2,3,4,5}

# %%
## pop method
removed_element=my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 5
# set()

# %%
## clear all the elements
my_set.clear()
print(my_set)
# Out:
# set()

# %%
## Set Memebership test
my_set={1,2,3,4,5}
print(3 in my_set)
print(10 in my_set)
# Out:
# True
# False

# %%
## MAthematical Operation
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}

### Union
union_set=set1.union(set2)
print(union_set)

## Intersection
intersection_set=set1.intersection(set2)
print(intersection_set)

# set1.intersection_update(set2)
# print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {4, 5, 6}

# %%
set2
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
set2.intersection_update(set1)
print(set2)
# Out:
# {4, 5, 6}

# %%
set1
# Out:
# {4, 5, 6}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}

## Difference 
print(set2.difference(set1))
# Out:
# {8, 9, 7}

# %%
set1

# %%
set2.difference(set1)

# %%
## Symmetric Difference
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
set1.symmetric_difference(set2)
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
text = "This is a sample text with several words. This text is for testing word count."
word_list = text.split('.')
print(word_list)
word_list_set = set(word_list)

for i in word_list_set:
    if i in word_list:  
        print(f"{i}: {word_list.count(i)}")
# Out:
# ['This is a sample text with several words', ' This text is for testing word count', '']
#  This text is for testing word count: 1
# : 1
# This is a sample text with several words: 1

# %%
## Sets Methods
set1={1,2,3,4,5}
set2={3,4,5}

## is subset
print(set1.issubset(set2))

print(set1.issuperset(set2))
# Out:
# False
# True

# %%
lst=[1,2,2,3,4,4,5]

set(lst)

# %%
### Counting Unique words in text

text="In In In In In this tutorial we are discussing about sets"
words=text.split()

## convert list of words to set to get unique words

unique_words=set(words)
print(unique_words)
print(len(unique_words))
# Out:
# {'discussing', 'sets', 'about', 'In', 'we', 'this', 'tutorial', 'are'}
# 8

# %% [markdown]
# #### Conclusion
# Sets are a powerful and flexible data type in Python that provide a way to store collections of unique elements. They support various operations such as union, intersection, difference, and symmetric difference, which are useful for mathematical computations. Understanding how to use sets and their associated methods can help you write more efficient and clean Python code, especially when dealing with unique collections and membership tests.
